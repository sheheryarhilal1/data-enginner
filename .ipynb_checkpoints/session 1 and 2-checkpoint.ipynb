# %%
print ("Hellow World")
# Out:
# Hellow World

# %%
"Hellow World" #string

# %%
123 #int

# %%
23.56 #foat

# %%
True False #Boolean

# %%
a1,_a,$a,(legal variabale) , .a(illegal variable)

# %%
a  = 5
b  = 6
c  = a+b
print (c)
# Out:
# 11

# %%
x = "sheheryar"
y = 10
z = x+y
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 x = "sheheryar"
#       2 y = 10
# ----> 3 z = x+y
#       4 print(z)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = "9"
b = 6
c = a+b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 a = "9"
#       2 b = 6
# ----> 3 c = a+b
#       4 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
f = "Sheheryar"
e = "Ahmed"
g = " "
h = f+g+e
print(h)
# Out:
# Sheheryar Ahmed

# %%
a = "ali"
a = "mughal"
print(a)
# Out:
# mughal

# %%
a = "7"
b = 5
c = a*b
print(c)
# Out:
# 77777

# %%
x = 7
y = x%3
print(y)
# Out:
# 1

# %%
a="5"
b=3
c=a-b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 a="5"
#       2 b=3
# ----> 3 c=a-b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
x = "8"
y = 4
z = x/y
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 x = "8"
#       2 y = 4
# ----> 3 z = x/y
#       4 print(z)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
2**3 #Power
# Out:
# 8

# %%
2+2j #complex data type
# Out:
# (2+2j)

# %%
type(2+2j) # to identify a type
# Out:
# complex

# %%
type("123")
# Out:
# str

# %% [markdown]
# # Typecasting

# %%
typr(123)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 typr(123)
#
# NameError: name 'typr' is not defined

# %%
type(123)
# Out:
# int

# %%
int("123")
# Out:
# 123

# %%
float("123.45")
# Out:
# 123.45

# %%
int('123.45')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 int('123.45')
#
# ValueError: invalid literal for int() with base 10: '123.45'

# %%
int(123.45)
# Out:
# 123

# %%
str(234)
# Out:
# '234'

# %%
print('ali's house')
# Out:
#   Cell In[28], line 1
#     print('ali's house')
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("ali's house")
# Out:
# ali's house

# %%
#\ (scap  character)
print('ali\'s house')
# Out:
# ali's house

# %%
# conditional statement
#comparision operetor
#==
#>
#<
#>=
#<=
#!=

# %%
x=5
if x>5:
    print ("True")
else :
    print("false")
# Out:
# false

# %%
x=5
if x!=5:
    print ("True")
else :
    print("false")
# Out:
# false

# %%
x=5
if x==5:
    print ("True")
else :
    print("false")
# Out:
# True

# %%
x=5
if x<=5:
    print ("True")
else :
    print("false")
# Out:
# True

# %%
x=5
if x>=5:
    print ("True")
else :
    print("false")
# Out:
# True

# %%
a = 7
if a ==7:
    print("correct")
elif a>=7:
    print("incorrect")
else:
    print("not correct")
# Out:
# correct

# %%
a = 7
if a !=7:
    print("correct")
elif a>7:
    print("incorrect")
else:
    print("not correct")
# Out:
# not correct

# %%
a = 7
if a <=7:
    print("correct")
elif a!=7:
    print("incorrect")
else:
    print("not correct")
# Out:
# correct

# %%
a = 8
if a <7:
    print("correct")
elif a>7:
    print("incorrect")
else:
    print("not correct")
# Out:
# incorrect

# %%
a = 7
if a <7:
    print("correct")
elif a>7:
    print("incorrect")
elif a==7:
    print("good")
else:
    print("not correct")
# Out:
# good

# %%
#logical operator
#and(both condition)
#or(single condition)
#not(inverse)

# %%
age =int (input("Enter your age:"))
gender = input("Enter your gender")
if age >18 and gender =="male":
    print("you have allow for ride")
else:
    print("you are not allow")
# Out:
# Enter your age: 25
# Enter your gender male
# you have allow for ride

# %%
age =int (input("Enter your age:"))
gender = input("Enter your gender")
if age <18 and gender =="male":
    print("you have allow for ride")
else:
    print("you are not allow")
# Out:
# Enter your age: 21
# Enter your gender male
# you are not allow

# %%
age =int (input("Enter your age:"))
gender = input("Enter your gender")
if age >=18 and gender =="male":
    print("you have allow for ride")
else:
    print("you are not allow")
# Out:
# Enter your age: 18
# Enter your gender male
# you have allow for ride

# %%
age =int (input("Enter your age:"))
gender = input("Enter your gender")
if age !=18 and gender =="male":
    print("you have allow for ride")
else:
    print("you are not allow")
# Out:
# Enter your age: 17
# Enter your gender male
# you have allow for ride

# %%
age =int (input("Enter your age:"))
gender = input("Enter your gender")
if age !=18 or gender =="male":
    print("you have allow for ride")
else:
    print("you are not allow")
# Out:
# Enter your age: 22
# Enter your gender female
# you are not allow

# %%
age =int (input("Enter your age:"))
gender = input("Enter your gender")
if age >18 or gender =="male":
    print("you have allow for ride")
else:
    print("you are not allow")
# Out:
# Enter your age: 16
# Enter your gender female
# you are not allow

# %%
# Input marks
m1 = int(input("Enter marks for subject 1: "))
m2 = int(input("Enter marks for subject 2: "))
m3 = int(input("Enter marks for subject 3: "))
m4 = int(input("Enter marks for subject 4: "))
m5 = int(input("Enter marks for subject 5: "))

# Total
total = m1 + m2 + m3 + m4 + m5

# Percentage
percentage = total / 5

# Grade
if percentage >= 90:
    print("Grade: A+")
elif percentage >= 80:
    print("Grade: A")
elif percentage >= 70:
    print("Grade: B")
elif percentage >= 60:
    print("Grade: C")
elif percentage >= 50:
    print("Grade: D")
else:
    print("Grade: Fail")

# Output
print("Total Marks:", total)
print("Percentage:", percentage)
# Out:
# Enter marks for subject 1:  22
# Enter marks for subject 2:  49
# Enter marks for subject 3:  63
# Enter marks for subject 4:  74
# Enter marks for subject 5:  99
# Grade: C
# Total Marks: 307
# Percentage: 61.4

# %%
#list
#in which we write group of element

# %%
name1 = "Daniyal"
name2 = "wasif"
nname3 = "Moiz"
name4 = "Hanan"

print(name2)

names=["daniyal","wasif","moiz","Hanan"]
print(names[1])
# Out:
# wasif
# wasif

# %%
names[3]
# Out:
# 'Hanan'

# %%
names[-1]
# Out:
# 'Hanan'

# %%
salaries =[20k]
# Out:
#   Cell In[32], line 1
#     salaries =[20k]
#                 ^
# SyntaxError: invalid decimal literal

# %%
salaries =['20k','30k','300k','500k']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '500k']

# %% [markdown]
# ## **Index**

# %% [markdown]
# #**Slicing**

# %%
salaries[1:4]
# Out:
# ['30k', '300k', '500k']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '500k']

# %%
salaries[-2:-3]
# Out:
# []

# %%
salaries[-5:-2]
# Out:
# ['20k', '30k']

# %%
salaries[2:]
# Out:
# ['300k', '500k']

# %%
salaries[:4]
# Out:
# ['20k', '30k', '300k', '500k']

# %%
salaries[:2:1]
# Out:
# ['20k', '30k']

# %%
salaries[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 salaries[5]
#
# IndexError: list index out of range

# %% [markdown]
# ###Data structure

# %%
list
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# #append (add the variable)

# %%
salaries.append()

# %%
len(salaries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 len(salaries)
#
# NameError: name 'salaries' is not defined

# %%
len(salaries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(salaries)
#
# NameError: name 'salaries' is not defined

# %%
salaries.append()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 salaries.append()
#
# NameError: name 'salaries' is not defined

# %%
len(salaries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 len(salaries)
#
# NameError: name 'salaries' is not defined

# %%
len(salaries)
# Out:
# 4

# %%
salaries.append("800K")

# %%
salaries
# Out:
# ['20k', '30k', '300k', '500k', '800K', '800K']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '500k']

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '500k', '800K', '800K']

# %%
salaries.insert(2,"800k")

# %%
salaries
# Out:
# ['20k', '30k', '800k', '800k', '300k', '500k', '800K', '800K']

# %%
salaries[2]='500k'

# %% [raw]
# salaries

# %%
salaries
# Out:
# ['20k', '30k', '500k', '800k', '300k', '500k', '800K', '800K']

# %%
salaries[1:4] = ['20k','30k','40k']

# %%
salaries
# Out:
# ['20k', '20k', '30k', '40k', '300k', '500k', '800K', '800K']

# %%
salaries.count('20k')
# Out:
# 2

# %% [markdown]
# #extend (merge two list and become one)

# %%
names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 names
#
# NameError: name 'names' is not defined

# %%
names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 names
#
# NameError: name 'names' is not defined

# %%
names
# Out:
# ['daniyal', 'wasif', 'moiz', 'Hanan']

# %%
salaries
# Out:
# ['20k', '20k', '30k', '40k', '300k', '500k', '800K', '800K']

# %%
bio = ['ahm',123,true]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 bio = ['ahm',123,true]
#
# NameError: name 'true' is not defined

# %%
bio = ['she',123,True]

# %%
bio
# Out:
# ['she', 123, True]

# %%
bio.extend(salaries)

# %%
bio
# Out:
# ['she', 123, True, '20k', '20k', '30k', '40k', '300k', '500k', '800K', '800K']
