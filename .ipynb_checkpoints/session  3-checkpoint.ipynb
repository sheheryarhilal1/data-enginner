# %%
#list in list
bios = ["sheheryar",22,"SE","sheheryar.hill.277@gmail.com",["ali",22,"DA","waqar2@gmail.com"],57]
bios
# Out:
# ['sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ['ali', 22, 'DA', 'waqar2@gmail.com'],
#  57]

# %%
len(bios)
# Out:
# 6

# %%
bios[4][3]
# Out:
# 'waqar2@gmail.com'

# %%
#list in list
bios = ["sheheryar",22,"SE","sheheryar.hill.277@gmail.com",["ali",22,"DA",[1,2,3],"waqar2@gmail.com"],57]
bios
# Out:
# ['sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ['ali', 22, 'DA', [1, 2, 3], 'waqar2@gmail.com'],
#  57]

# %%
bios[4][3][-1]
# Out:
# 3

# %%
#slicer concept use
bios[4][:3]
# Out:
# ['ali', 22, 'DA']

# %% [markdown]
# ## ***Strings***

# %% [raw]
# ""
# ''
# ''' '''
# """ """

# %%
'we have been completed 3 
session'
# Out:
#   Cell In[14], line 1
#     'we have been completed 3
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('''we have been completed 3 
session''')
# Out:
# we have been completed 3
# session

# %%
dir('')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
#remove extra space(.strip() use)
"  hell world   ".strip()
# Out:
# 'hell world'

# %%
#remove extra space from right(.rstrip() use)
"  hell world   ".rstrip()
# Out:
# '  hell world'

# %%
#remove extra space from left (.lstrip() use)
"  hell world   ".lstrip()
# Out:
# 'hell world   '

# %%
#.split() is use to split a sentence
"we have been completed 3 session".split()
# Out:
# ['we', 'have', 'been', 'completed', '3', 'session']

# %%
"sheheryar.hill.277@gmail.com".split('@')
# Out:
# ['sheheryar.hill.277', 'gmail.com']

# %%
"sheheryar.hill.277@gmail.com".split('.')
# Out:
# ['sheheryar', 'hill', '277@gmail', 'com']

# %%
#.split() is not use to split a sentence if sentence is in list form they generate error which is attribute error
["we have been completed 3 session"].split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 #.split() is not use to split a sentence if sentence is in list form they generate error which is attribute error
# ----> 2 ["we have been completed 3 session"].split()
#
# AttributeError: 'list' object has no attribute 'split'

# %% [markdown]
# # ***Tuple***

# %%
#when we use round bracket it means we work with tuple
tuple_bios = ("sheheryar",22,"SE","sheheryar.hill.277@gmail.com",("ali",22,"DA","waqar2@gmail.com"),57)
tuple_bios
# Out:
# ('sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ('ali', 22, 'DA', 'waqar2@gmail.com'),
#  57)

# %%
#difference between tuple and list is that mutualable and unmutuable we not modify tuple list should be modify
tuple_bios = ("sheheryar",22,"SE","sheheryar.hill.277@gmail.com",["ali",22,"DA","waqar24@gmail.com"],57)
tuple_bios
# Out:
# ('sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ['ali', 22, 'DA', 'waqar24@gmail.com'],
#  57)

# %%
tuple_bios[4][1]='24'
tuple_bios
# Out:
# ('sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ['ali', '24', 'DA', 'waqar24@gmail.com'],
#  57)

# %%
tuple_bios[2]
# Out:
# 'SE'

# %%
tuple_bios[2] ="DA"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 tuple_bios[2] ="DA"
#
# TypeError: 'tuple' object does not support item assignment

# %%
num1=(1,4)
num2=(5,7)

# %%
num1*3
# Out:
# (1, 4, 1, 4, 1, 4)

# %%
num1 + num2
# Out:
# (1, 4, 5, 7)

# %%
#unpacking done in list as well as in tuple

bios
# Out:
# ['sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ['ali', 22, 'DA', [1, 2, 3], 'waqar2@gmail.com'],
#  57]

# %%
tuple_bios
# Out:
# ('sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ['ali', '24', 'DA', 'waqar24@gmail.com'],
#  57)

# %%
name,age,des,email,other_info,num =tuple_bios

# %%
name
# Out:
# 'sheheryar'

# %%
num
# Out:
# 57

# %%
#other values count when we place '*' to the word
name,age,des,email,*other_info, =tuple_bios

# %%
tuple_bios
# Out:
# ('sheheryar',
#  22,
#  'SE',
#  'sheheryar.hill.277@gmail.com',
#  ['ali', '24', 'DA', 'waqar24@gmail.com'],
#  57)

# %%
name
# Out:
# 'sheheryar'
